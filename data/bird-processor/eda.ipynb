# %%
from datasets import load_dataset
import sqlparse

ds = load_dataset("xu3kev/BIRD-SQL-data-train")
# Out:
# Using the latest cached version of the dataset since xu3kev/BIRD-SQL-data-train couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /Users/cshorten/.cache/huggingface/datasets/xu3kev___bird-sql-data-train/default/0.0.0/9122256f9d14752ed80fb9b7d158e21d9f9261aa (last modified on Fri Dec 27 09:41:00 2024).

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['db_id', 'question', 'evidence', 'SQL', 'schema'],
#         num_rows: 9428
#     })
# })

# %%
ds["train"][0]
# Out:
# {'db_id': 'video_games',
#  'question': 'List down at least five publishers of the games with number of sales less than 10000.',
#  'evidence': 'publishers refers to publisher_name; number of sales less than 10000 refers to num_sales < 0.1;',
#  'SQL': "SELECT T.publisher_name FROM ( SELECT DISTINCT T5.publisher_name FROM region AS T1 INNER JOIN region_sales AS T2 ON T1.id = T2.region_id INNER JOIN game_platform AS T3 ON T2.game_platform_id = T3.id INNER JOIN game_publisher AS T4 ON T3.game_publisher_id = T4.id INNER JOIN publisher AS T5 ON T4.publisher_id = T5.id WHERE T1.region_name = 'North America' AND T2.num_sales * 100000 < 10000 LIMIT 5 ) t",
#  'schema': 'CREATE TABLE genre\n(\n    id         INTEGER not null\n            primary key,\n    genre_name TEXT default NULL\n);\nCREATE TABLE game\n(\n    id        INTEGER not null\n            primary key,\n    genre_id  INTEGER          default NULL,\n    game_name TEXT default NULL,\n    foreign key (genre_id) references genre(id)\n);\nCREATE TABLE platform\n(\n    id            INTEGER not null\n            primary key,\n    platform_name TEXT default NULL\n);\nCREATE TABLE publisher\n(\n    id             INTEGER not null\n            primary key,\n    publisher_name TEXT default NULL\n);\nCREATE TABLE game_publisher\n(\n    id           INTEGER not null\n            primary key,\n    game_id      INTEGER default NULL,\n    publisher_id INTEGER default NULL,\n    foreign key (game_id) references game(id),\n    foreign key (publisher_id) references publisher(id)\n);\nCREATE TABLE game_platform\n(\n    id                INTEGER not null\n            primary key,\n    game_publisher_id INTEGER default NULL,\n    platform_id       INTEGER default NULL,\n    release_year      INTEGER default NULL,\n    foreign key (game_publisher_id) references game_publisher(id),\n    foreign key (platform_id) references platform(id)\n);\nCREATE TABLE region\n(\n    id          INTEGER not null\n            primary key,\n    region_name TEXT default NULL\n);\nCREATE TABLE region_sales\n(\n    region_id        INTEGER           default NULL,\n    game_platform_id INTEGER           default NULL,\n    num_sales        REAL default NULL,\n    foreign key (game_platform_id) references game_platform(id),\n    foreign key (region_id) references region(id)\n);\n'}

# %%
join_count = 0
total_count = 0
non_join_queries = []

for row in ds["train"]:
    sql = row["SQL"]
    total_count += 1
    if "JOIN" in sql.upper():
        join_count += 1
    else:
        non_join_queries.append(sql)

print(f"Number of SQL statements containing JOIN: {join_count}")
print(f"Total number of SQL statements: {total_count}")
print(f"Percentage: {(join_count/total_count)*100:.2f}%")

print("\nSample of queries without JOINs:")
for i, query in enumerate(non_join_queries[:3]):  # Show first 3 non-join queries
    print(f"\nQuery {i+1}:")
    print(query)
# Out:
# Number of SQL statements containing JOIN: 7212
# Total number of SQL statements: 9428
# Percentage: 76.50%
#
# Sample of queries without JOINs:
#
# Query 1:
# SELECT COUNT(name) FROM director WHERE director = 'Wolfgang Reitherman'
#
# Query 2:
# SELECT COUNT(bioguide) FROM `current-terms` WHERE class IS NULL
#
# Query 3:
# SELECT character_id FROM paragraphs WHERE PlainText = 'O my poor brother! and so perchance may he be.'

# %%
# Filter out queries containing AS or HAVING
filtered_queries = [
    query for query in non_join_queries 
    if "AS" not in query.upper() and "HAVING" not in query.upper()
]

print(f"Original number of queries: {len(non_join_queries)}")
print(f"Number of queries after filtering: {len(filtered_queries)}")
# Out:
# Original number of queries: 2216
# Number of queries after filtering: 1547

# %%
filtered_queries[:20]
# Out:
# ["SELECT COUNT(name) FROM director WHERE director = 'Wolfgang Reitherman'",
#  "SELECT character_id FROM paragraphs WHERE PlainText = 'O my poor brother! and so perchance may he be.'",
#  'SELECT city FROM Business ORDER BY review_count DESC LIMIT 1',
#  "SELECT COUNT(OrderQty) FROM SalesOrderDetail WHERE ProductID IN ( SELECT ProductID FROM Product WHERE Name = 'Minipump' )",
#  'SELECT COUNT(rating_id) FROM ratings WHERE movie_id = ( SELECT movie_id FROM movies ORDER BY movie_popularity DESC LIMIT 1 )',
#  "SELECT MAX(age) FROM client WHERE sex = 'Male'",
#  "SELECT Name FROM Culture WHERE CultureID = 'fr'",
#  "SELECT COUNT(ID) FROM Customers WHERE OCCUPATION = 'Machine-op-inspct' AND age > 30",
#  "SELECT COUNT(ShortName) FROM Country WHERE ShortName LIKE 'A%' UNION SELECT alpha2code FROM country WHERE shortname LIKE 'A%'",
#  "SELECT item_nbr FROM sales_in_weather WHERE `date` = '2012-01-01' AND store_nbr = 1 ORDER BY units DESC LIMIT 1",
#  'SELECT s_name FROM supplier ORDER BY s_acctbal DESC LIMIT 3',
#  "SELECT birth_country FROM Person WHERE name = 'Michael Preston'",
#  "SELECT GEOID FROM Customers WHERE OCCUPATION = 'Handlers-cleaners'",
#  "SELECT COUNT(customerNumber) FROM customers WHERE creditLimit = 0 AND country = 'Germany'",
#  'SELECT COUNT(l_orderkey) FROM lineitem WHERE l_discount = 0',
#  'SELECT Forks, Url FROM Repo WHERE Forks = ( SELECT MAX(Forks) FROM Repo )',
#  'SELECT popularity FROM movie ORDER BY vote_COUNT DESC LIMIT 1',
#  'SELECT isbn13 FROM book WHERE num_pages < 140 AND num_pages > 135',
#  "SELECT OctL, tmID FROM TeamSplits WHERE year = '2006' ORDER BY OctL DESC LIMIT 1",
#  'SELECT projectid FROM projects ORDER BY total_price_including_optional_support DESC LIMIT 1']

# %%
class SQLToWeaviateParser:
    def __init__(self):
        self.agg_mapping = {
            'COUNT': 'COUNT',
            'MIN': 'MIN',
            'MAX': 'MAX',
            'AVG': 'MEAN',
            'SUM': 'SUM',
            'MODE': 'MODE',
            'MEDIAN': 'MEDIAN'
        }

    def parse_sql(self, sql: str) -> dict:
        parts = sql.upper().split()
        query = {"collection_name": ""}
        
        # Get collection name
        try:
            from_index = parts.index("FROM")
            query["collection_name"] = parts[from_index + 1].lower()
        except:
            pass

        # Handle aggregations in SELECT clause
        select_index = parts.index("SELECT")
        agg_part = parts[select_index + 1]
        if "COUNT" in agg_part:
            field = agg_part.replace("COUNT(", "").replace(")", "").lower()
            query["integer_property_aggregation"] = {
                "property_name": field,
                "metrics": "COUNT"
            }
        elif any(agg in agg_part for agg in self.agg_mapping.keys()):
            for agg in self.agg_mapping.keys():
                if agg in agg_part:
                    field = agg_part.replace(f"{agg}(", "").replace(")", "").lower()
                    query["integer_property_aggregation"] = {
                        "property_name": field,
                        "metrics": self.agg_mapping[agg]
                    }
                    break
            
        # Get where conditions
        try:
            where_index = parts.index("WHERE")
            property_name = parts[where_index + 1].lower()
            operator = parts[where_index + 2]
            value = parts[where_index + 3]
            
            try:
                value = float(value)
                query["integer_property_filter"] = {
                    "property_name": property_name,
                    "operator": operator,
                    "value": value
                }
            except ValueError:
                if value.lower() in ('true', 'false'):
                    query["boolean_property_filter"] = {
                        "property_name": property_name,
                        "operator": operator,
                        "value": value.lower() == 'true'
                    }
                else:
                    query["text_property_filter"] = {
                        "property_name": property_name,
                        "operator": operator,
                        "value": value.strip("'\"")
                    }
        except:
            pass

        # Handle GROUP BY
        try:
            group_index = parts.index("GROUP")
            if parts[group_index + 1] == "BY":
                query["groupby_property"] = parts[group_index + 2].lower()
        except:
            pass
            
        return query

parser = SQLToWeaviateParser()
test_queries = [
    "SELECT COUNT(views) FROM videos",
    "SELECT * FROM videos WHERE views > 1000",
    "SELECT AVG(duration) FROM videos",
    "SELECT * FROM videos WHERE is_premium = true",
    "SELECT * FROM videos WHERE title = 'Python Tutorial'",
    "SELECT * FROM videos GROUP BY category"
]

for query in test_queries:
    weaviate_query = parser.parse_sql(query)
    print(f"\nSQL: {query}")
    print("Weaviate:", weaviate_query)
# Out:
# SQL: SELECT COUNT(views) FROM videos
# Weaviate: {'collection_name': 'videos', 'integer_property_aggregation': {'property_name': 'views', 'metrics': 'COUNT'}}
#
# SQL: SELECT * FROM videos WHERE views > 1000
# Weaviate: {'collection_name': 'videos', 'integer_property_filter': {'property_name': 'views', 'operator': '>', 'value': 1000.0}}
#
# SQL: SELECT AVG(duration) FROM videos
# Weaviate: {'collection_name': 'videos', 'integer_property_aggregation': {'property_name': 'duration', 'metrics': 'MEAN'}}
#
# SQL: SELECT * FROM videos WHERE is_premium = true
# Weaviate: {'collection_name': 'videos', 'boolean_property_filter': {'property_name': 'is_premium', 'operator': '=', 'value': True}}
#
# SQL: SELECT * FROM videos WHERE title = 'Python Tutorial'
# Weaviate: {'collection_name': 'videos', 'text_property_filter': {'property_name': 'title', 'operator': '=', 'value': 'PYTHON'}}
#
# SQL: SELECT * FROM videos GROUP BY category
# Weaviate: {'collection_name': 'videos', 'groupby_property': 'category'}

# %%
import json
import re

def sql_to_weaviate_schema(sql_schema):
    # Parse CREATE TABLE statements
    table_pattern = r"CREATE TABLE (\w+)\s*\((.*?)\);"
    tables = re.findall(table_pattern, sql_schema, re.DOTALL)
    
    collections = []
    for table_name, table_content in tables:
        # Parse columns
        column_pattern = r"(\w+)\s+(INTEGER|TEXT|REAL)(?:\s+not null)?(?:\s+primary key)?(?:\s+default NULL)?"
        columns = re.findall(column_pattern, table_content)
        
        properties = []
        for col_name, col_type in columns:
            if col_name == 'id':  # Skip id columns as Weaviate handles these automatically
                continue
                
            data_type = ["number"] if col_type in ["INTEGER", "REAL"] else ["string"]
            
            properties.append({
                "name": col_name,
                "data_type": data_type,
                "description": f"The {col_name.replace('_', ' ')} of the {table_name}."
            })
            
        if properties:  # Only add tables with properties
            collections.append({
                "name": table_name.capitalize(),
                "properties": properties,
                "envisioned_use_case_overview": f"This collection stores information about {table_name.replace('_', ' ')}s."
            })
    
    return {
        "weaviate_collections": collections
    }
# Process first schema and save
for row in ds["train"]:
    schema, SQL_query, nl_command = row["schema"], row["SQL"], row["question"]
    weaviate_schema = sql_to_weaviate_schema(schema)
    weaviate_query = parser.parse_sql(SQL_query)
    
    output = {
        "weaviate_collections": weaviate_schema["weaviate_collections"],
        "weaviate_query": weaviate_query,
        "natural_language_query": nl_command
    }

    print(output)
    
    with open("bird-to-weaviate.json", "w") as f:
        json.dump(output, f, indent=2)
    break
# Out:
# {'weaviate_collections': [{'name': 'Genre', 'properties': [{'name': 'genre_name', 'data_type': ['string'], 'description': 'The genre name of the genre.'}], 'envisioned_use_case_overview': 'This collection stores information about genres.'}, {'name': 'Game', 'properties': [{'name': 'genre_id', 'data_type': ['number'], 'description': 'The genre id of the game.'}, {'name': 'game_name', 'data_type': ['string'], 'description': 'The game name of the game.'}], 'envisioned_use_case_overview': 'This collection stores information about games.'}, {'name': 'Platform', 'properties': [{'name': 'platform_name', 'data_type': ['string'], 'description': 'The platform name of the platform.'}], 'envisioned_use_case_overview': 'This collection stores information about platforms.'}, {'name': 'Publisher', 'properties': [{'name': 'publisher_name', 'data_type': ['string'], 'description': 'The publisher name of the publisher.'}], 'envisioned_use_case_overview': 'This collection stores information about publishers.'}, {'name': 'Game_publisher', 'properties': [{'name': 'game_id', 'data_type': ['number'], 'description': 'The game id of the game_publisher.'}, {'name': 'publisher_id', 'data_type': ['number'], 'description': 'The publisher id of the game_publisher.'}], 'envisioned_use_case_overview': 'This collection stores information about game publishers.'}, {'name': 'Game_platform', 'properties': [{'name': 'game_publisher_id', 'data_type': ['number'], 'description': 'The game publisher id of the game_platform.'}, {'name': 'platform_id', 'data_type': ['number'], 'description': 'The platform id of the game_platform.'}, {'name': 'release_year', 'data_type': ['number'], 'description': 'The release year of the game_platform.'}], 'envisioned_use_case_overview': 'This collection stores information about game platforms.'}, {'name': 'Region', 'properties': [{'name': 'region_name', 'data_type': ['string'], 'description': 'The region name of the region.'}], 'envisioned_use_case_overview': 'This collection stores information about regions.'}, {'name': 'Region_sales', 'properties': [{'name': 'region_id', 'data_type': ['number'], 'description': 'The region id of the region_sales.'}, {'name': 'game_platform_id', 'data_type': ['number'], 'description': 'The game platform id of the region_sales.'}, {'name': 'num_sales', 'data_type': ['number'], 'description': 'The num sales of the region_sales.'}], 'envisioned_use_case_overview': 'This collection stores information about region saless.'}], 'weaviate_query': {'collection_name': '(', 'text_property_filter': {'property_name': 't1.region_name', 'operator': '=', 'value': 'NORTH'}}, 'natural_language_query': 'List down at least five publishers of the games with number of sales less than 10000.'}
